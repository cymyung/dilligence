# %% [markdown]
# <a href="https://colab.research.google.com/github/cymyung/dilligence/blob/main/coretime240405.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#240405 오전 수정1122

# %%
import pandas as pd
from numpy import nan
from datetime import datetime as dt

# %%
df = pd.read_excel('/content/근태.xlsx')
df
# Out:
#          부서   성명      원번         일 요일  일별근로시간(분)   일별근로시간         출/퇴근  \
# 0        감사  이제항  951209  20240325  월        442     7:22  08:58~17:20
# 1        감사  이제항  951209  20240326  화        428     7:08  09:03~17:11
# 2        감사  이제항  951209  20240327  수        501  1일 0:21  08:02~17:23
# 3        감사  이제항  951209  20240328  목        452     7:32  08:34~17:06
# 4        감사  이제항  951209  20240329  금        443     7:23  08:19~16:42
# ...     ...  ...     ...       ... ..        ...      ...          ...
# 4342  안전기술원  윤수지  201923  20240327  수          0      NaN          NaN
# 4343  안전기술원  윤수지  201923  20240328  목          0      NaN          NaN
# 4344  안전기술원  윤수지  201923  20240329  금          0      NaN          NaN
# 4345  안전기술원  윤수지  201923  20240330  토          0      NaN          NaN
# 4346  안전기술원  윤수지  201923  20240331  일          0      NaN          NaN
#
#      출/퇴근(시간)   출장 출장(시간)   휴가 휴가(시간)  조식여부 석식여부
# 0        7:22  NaN    NaN  NaN    NaN   NaN  NaN
# ...

# %%
df2 = df.loc[:,['부서','성명','원번','일','요일','출/퇴근','출장','휴가']]
df2
# Out:
#          부서   성명      원번         일 요일         출/퇴근   출장   휴가
# 0        감사  이제항  951209  20240325  월  08:58~17:20  NaN  NaN
# 1        감사  이제항  951209  20240326  화  09:03~17:11  NaN  NaN
# 2        감사  이제항  951209  20240327  수  08:02~17:23  NaN  NaN
# 3        감사  이제항  951209  20240328  목  08:34~17:06  NaN  NaN
# 4        감사  이제항  951209  20240329  금  08:19~16:42  NaN  NaN
# ...     ...  ...     ...       ... ..          ...  ...  ...
# 4342  안전기술원  윤수지  201923  20240327  수          NaN  NaN  NaN
# 4343  안전기술원  윤수지  201923  20240328  목          NaN  NaN  NaN
# 4344  안전기술원  윤수지  201923  20240329  금          NaN  NaN  NaN
# 4345  안전기술원  윤수지  201923  20240330  토          NaN  NaN  NaN
# 4346  안전기술원  윤수지  201923  20240331  일          NaN  NaN  NaN
#
# [4347 rows x 8 columns]

# %%
df2 = df2.rename(columns = {'일':'날짜'})
df2
# Out:
#          부서   성명      원번        날짜 요일         출/퇴근   출장   휴가
# 0        감사  이제항  951209  20240325  월  08:58~17:20  NaN  NaN
# 1        감사  이제항  951209  20240326  화  09:03~17:11  NaN  NaN
# 2        감사  이제항  951209  20240327  수  08:02~17:23  NaN  NaN
# 3        감사  이제항  951209  20240328  목  08:34~17:06  NaN  NaN
# 4        감사  이제항  951209  20240329  금  08:19~16:42  NaN  NaN
# ...     ...  ...     ...       ... ..          ...  ...  ...
# 4342  안전기술원  윤수지  201923  20240327  수          NaN  NaN  NaN
# 4343  안전기술원  윤수지  201923  20240328  목          NaN  NaN  NaN
# 4344  안전기술원  윤수지  201923  20240329  금          NaN  NaN  NaN
# 4345  안전기술원  윤수지  201923  20240330  토          NaN  NaN  NaN
# 4346  안전기술원  윤수지  201923  20240331  일          NaN  NaN  NaN
#
# [4347 rows x 8 columns]

# %%
df2['연'] = df2['날짜'].astype(str).str[:4 ]
df2['월'] = df2['날짜'].astype(str).str[4:6]
df2['일'] = df2['날짜'].astype(str).str[6: ]
df2
# Out:
#          부서   성명      원번        날짜 요일         출/퇴근   출장   휴가     연   월   일
# 0        감사  이제항  951209  20240325  월  08:58~17:20  NaN  NaN  2024  03  25
# 1        감사  이제항  951209  20240326  화  09:03~17:11  NaN  NaN  2024  03  26
# 2        감사  이제항  951209  20240327  수  08:02~17:23  NaN  NaN  2024  03  27
# 3        감사  이제항  951209  20240328  목  08:34~17:06  NaN  NaN  2024  03  28
# 4        감사  이제항  951209  20240329  금  08:19~16:42  NaN  NaN  2024  03  29
# ...     ...  ...     ...       ... ..          ...  ...  ...   ...  ..  ..
# 4342  안전기술원  윤수지  201923  20240327  수          NaN  NaN  NaN  2024  03  27
# 4343  안전기술원  윤수지  201923  20240328  목          NaN  NaN  NaN  2024  03  28
# 4344  안전기술원  윤수지  201923  20240329  금          NaN  NaN  NaN  2024  03  29
# 4345  안전기술원  윤수지  201923  20240330  토          NaN  NaN  NaN  2024  03  30
# 4346  안전기술원  윤수지  201923  20240331  일          NaN  NaN  NaN  2024  03  31
#
# [4347 rows x 11 columns]

# %%
df3 = df2[['부서','성명','원번','연','월','일','요일','출/퇴근','출장','휴가']]

# %%
df3
# Out:
#          부서   성명      원번     연   월   일 요일         출/퇴근   출장   휴가
# 0        감사  이제항  951209  2024  03  25  월  08:58~17:20  NaN  NaN
# 1        감사  이제항  951209  2024  03  26  화  09:03~17:11  NaN  NaN
# 2        감사  이제항  951209  2024  03  27  수  08:02~17:23  NaN  NaN
# 3        감사  이제항  951209  2024  03  28  목  08:34~17:06  NaN  NaN
# 4        감사  이제항  951209  2024  03  29  금  08:19~16:42  NaN  NaN
# ...     ...  ...     ...   ...  ..  .. ..          ...  ...  ...
# 4342  안전기술원  윤수지  201923  2024  03  27  수          NaN  NaN  NaN
# 4343  안전기술원  윤수지  201923  2024  03  28  목          NaN  NaN  NaN
# 4344  안전기술원  윤수지  201923  2024  03  29  금          NaN  NaN  NaN
# 4345  안전기술원  윤수지  201923  2024  03  30  토          NaN  NaN  NaN
# 4346  안전기술원  윤수지  201923  2024  03  31  일          NaN  NaN  NaN
#
# [4347 rows x 10 columns]

# %%
df4 = df3.drop(df3[df3['부서'] == '안전기술원'].index)
df4
# Out:
#        부서   성명      원번     연   월   일 요일         출/퇴근   출장   휴가
# 0      감사  이제항  951209  2024  03  25  월  08:58~17:20  NaN  NaN
# 1      감사  이제항  951209  2024  03  26  화  09:03~17:11  NaN  NaN
# 2      감사  이제항  951209  2024  03  27  수  08:02~17:23  NaN  NaN
# 3      감사  이제항  951209  2024  03  28  목  08:34~17:06  NaN  NaN
# 4      감사  이제항  951209  2024  03  29  금  08:19~16:42  NaN  NaN
# ...   ...  ...     ...   ...  ..  .. ..          ...  ...  ...
# 4118  교수실  이해단  201828  2024  03  27  수  09:48~18:47  NaN  NaN
# 4119  교수실  이해단  201828  2024  03  28  목  09:53~17:40  NaN  NaN
# 4120  교수실  이해단  201828  2024  03  29  금  09:56~14:45  NaN  NaN
# 4121  교수실  이해단  201828  2024  03  30  토          NaN  NaN  NaN
# 4122  교수실  이해단  201828  2024  03  31  일          NaN  NaN  NaN
#
# [4123 rows x 10 columns]

# %%
df5 = df4.loc[75:85,:]

# %%
df6 = df5.copy()
df6
# Out:
#       부서   성명      원번     연   월   일 요일                     출/퇴근   출장  \
# 75  전문위원  정승영  200207  2024  03  30  토                      NaN  NaN
# 76  전문위원  정승영  200207  2024  03  31  일                      NaN  NaN
# 77  전문위원  지성현  970805  2024  03  25  월              15:40~20:15  NaN
# 78  전문위원  지성현  970805  2024  03  26  화              09:24~17:22  NaN
# 79  전문위원  지성현  970805  2024  03  27  수  08:40~09:05,10:41~19:52  NaN
# 80  전문위원  지성현  970805  2024  03  28  목  08:45~14:30,17:36~19:57  NaN
# 81  전문위원  지성현  970805  2024  03  29  금  08:30~15:29,16:59~18:31  NaN
# 82  전문위원  지성현  970805  2024  03  30  토                      NaN  NaN
# 83  전문위원  지성현  970805  2024  03  31  일                      NaN  NaN
# 84  전문위원  장재권  200006  2024  03  25  월              07:00~17:20  NaN
# 85  전문위원  장재권  200006  2024  03  26  화              09:24~16:01  NaN
#
#                                    휴가
# 75                                NaN
# 76                                NaN
# ...

# %%
# 코딩 순서
# 출/퇴근, 출장, 휴가를 합쳐서 한개의 리스트내에 튜플이 여러개 들어가 있는 형태로 만든다.
# 튜플1개는 시작시각, 종료시각으로 구성된다.
# [(시작1,종료1),(시작2,종료2),(시작3,종료3)] 형태가 된다.
#
# 출/퇴근 데이터 한개를 먼저 [(시작1,종료1),(시작2,종료2)] 형태로 만들고,
# 출장도 [(시작1,종료1),(시작2,종료2)] 형태로 만들어서 두 리스트를 합친다.
#
# 출/퇴근 데이터 한개를 [(시작1,종료1),(시작2,종료2)]로 만드는 순서
# if로 검사하여 isnull  = True이면 다음으로
# if not null 이면, ',' 갯수

# %%
df6.index = range(0,len(df6.index))
df6
# Out:
#       부서   성명      원번     연   월   일 요일                     출/퇴근   출장  \
# 0   전문위원  정승영  200207  2024  03  30  토                      NaN  NaN
# 1   전문위원  정승영  200207  2024  03  31  일                      NaN  NaN
# 2   전문위원  지성현  970805  2024  03  25  월              15:40~20:15  NaN
# 3   전문위원  지성현  970805  2024  03  26  화              09:24~17:22  NaN
# 4   전문위원  지성현  970805  2024  03  27  수  08:40~09:05,10:41~19:52  NaN
# 5   전문위원  지성현  970805  2024  03  28  목  08:45~14:30,17:36~19:57  NaN
# 6   전문위원  지성현  970805  2024  03  29  금  08:30~15:29,16:59~18:31  NaN
# 7   전문위원  지성현  970805  2024  03  30  토                      NaN  NaN
# 8   전문위원  지성현  970805  2024  03  31  일                      NaN  NaN
# 9   전문위원  장재권  200006  2024  03  25  월              07:00~17:20  NaN
# 10  전문위원  장재권  200006  2024  03  26  화              09:24~16:01  NaN
#
#                                    휴가
# 0                                 NaN
# 1                                 NaN
# ...

# %%
df6 = df6.replace({'NaN':nan})
df6
df6['출/퇴근'].isnull()  # isnull 은 시리즈 전체에 대해서..
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# Name: 출/퇴근, dtype: bool

# %%
df6['출/퇴근'].isnull()[0]
# Out:
# True

# %%
for times in df6['출/퇴근']:
    if times.notnull():
        print(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-186-8f80fefabea5> in <cell line: 1>()
#       1 for times in df6['출/퇴근']:
# ----> 2     if times.notnull():
#       3         print(1)
#
# AttributeError: 'float' object has no attribute 'notnull'

# %%
type(df6['출/퇴근'])
# Out:
# pandas.core.series.Series

# %%
df7 = df6.replace({'NaN':nan})
df5['출/퇴근'].isnull()
# Out:
# 75     True
# 76     True
# 77    False
# 78    False
# 79    False
# 80    False
# 81    False
# 82     True
# 83     True
# 84    False
# 85    False
# Name: 출/퇴근, dtype: bool

# %%
df4['출/퇴근'][28].isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-4d1dfb503f97> in <cell line: 1>()
# ----> 1 df4['출/퇴근'][28].isnull()
#
# AttributeError: 'float' object has no attribute 'isnull'

# %%
# 출/퇴근 칼럼의 , 가 몇개인지 count
df7['출/퇴근'][79].count(',')
# Out:
# 1

# %%
# ,가 한개이상인 경우 분리
times = df7['출/퇴근'][79].split(',')
times
# Out:
# ['08:40~09:05', '10:41~19:52']

# %%
times[0].split('~')
# Out:
# ['08:40', '09:05']

# %%
t00 = dt.strptime(times[0].split('~')[0],'%H:%M').time()
t01 = dt.strptime(times[0].split('~')[1],'%H:%M').time()
t10 = dt.strptime(times[1].split('~')[0],'%H:%M').time()
t11 = dt.strptime(times[1].split('~')[1],'%H:%M').time()
print(t00, t01, t10, t11)
# Out:
# 09:50:00 18:37:00 20:27:00 22:00:00

# %%
print([(t00,t01),(t10,t11)])
# Out:
# [(datetime.time(9, 50), datetime.time(18, 37)), (datetime.time(20, 27), datetime.time(22, 0))]

# %%
t00 < t10
# Out:
# True

# %%
df4['출/퇴근'].str.split(',').head(35)
# Out:
# 0                  [08:58~17:20]
# 1                  [09:03~17:11]
# 2                  [08:02~17:23]
# 3                  [08:34~17:06]
# 4                  [08:19~16:42]
# 5                            NaN
# 6                            NaN
# 7                  [11:14~18:47]
# 8                  [07:21~17:08]
# 9                  [07:23~19:20]
# 10                 [07:42~17:23]
# 11                 [07:07~09:58]
# 12                           NaN
# 13                           NaN
# 14                 [09:15~21:38]
# 15                 [09:23~19:24]
# 16                 [08:57~18:21]
# 17                 [09:30~21:04]
# 18                 [09:20~15:47]
# 19                           NaN
# 20                           NaN
# 21                           NaN
# 22                           NaN
# 23                           NaN
# 24                           NaN
# 25                           NaN
# 26                           NaN
# 27                           NaN
# ...

# %%
a = [1,2,3]
b = ['a','b','c']

# %%
a + b
# Out:
# [1, 2, 3, 'a', 'b', 'c']
