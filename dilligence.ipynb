# %% [markdown]
# <a href="https://colab.research.google.com/github/cymyung/dilligence/blob/main/dilligence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
## test

# %%
#a2301 = pd.read_excel('https://raw.githubusercontent.com/cymyung/dilligence/main/2023_01.xlsx')

# %%
a2301

# %%
a2302 = pd.read_excel('https://raw.githubusercontent.com/cymyung/dilligence/main/2023_01_2.xlsx')
a2302
# Out:
#                  부서   성명      원번         일 요일  일별근로시간(분)   일별근로시간  \
# 0             심사총괄실  민기훈  201913  20230126  목        622  1일 2:22
# 1       중대사고·리스크평가실  강경민  201033  20230120  금        615  1일 2:15
# 2       중대사고·리스크평가실  김은호  201638  20230117  화        725  1일 4:05
# 3             품질평가실  장현섭  200205  20230106  금        442     7:22
# 4             품질평가실  장현섭  200205  20230116  월        402     6:42
# 5             품질평가실  김연승  201037  20230116  월        366     6:06
# 6          의료방사선평가실  김지영  201038  20230111  수        510  1일 0:30
# 7           한울주재검사팀  장도윤  201553  20230106  금        356     5:56
# 8           한울주재검사팀  장도윤  201553  20230120  금        403     6:43
# 9           한울주재검사팀  장도윤  201553  20230127  금        352     5:52
# 10       방사선·폐기물평가실  김병일  201508  20230112  목        534  1일 0:54
# 11         방사선사건평가실  박창수  200708  20230104  수        443     7:23
# 12      공항만방사선감시평가실  이종현  201958  20230117  화        401     6:41
# ...

# %%
a2302['휴가']   =a2302['휴가'].str.replace(r'\(\w+\)','')
#a2302['휴가']   =a2302['휴가'].str.split(',')
#a2302['출장']   =a2302['출장'].str.split(',')
#a2302['출/퇴근']=a2302['출/퇴근'].str.split(',')
a2302
# Out:
# <ipython-input-30-f02567471195>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   a2302['휴가']   =a2302['휴가'].str.replace(r'\(\w+\)','')
#                  부서   성명      원번         일 요일  일별근로시간(분)   일별근로시간  \
# 0             심사총괄실  민기훈  201913  20230126  목        622  1일 2:22
# 1       중대사고·리스크평가실  강경민  201033  20230120  금        615  1일 2:15
# 2       중대사고·리스크평가실  김은호  201638  20230117  화        725  1일 4:05
# 3             품질평가실  장현섭  200205  20230106  금        442     7:22
# 4             품질평가실  장현섭  200205  20230116  월        402     6:42
# 5             품질평가실  김연승  201037  20230116  월        366     6:06
# 6          의료방사선평가실  김지영  201038  20230111  수        510  1일 0:30
# 7           한울주재검사팀  장도윤  201553  20230106  금        356     5:56
# 8           한울주재검사팀  장도윤  201553  20230120  금        403     6:43
# 9           한울주재검사팀  장도윤  201553  20230127  금        352     5:52
# ...

# %%
a2302_1 = a2302
a2302_1
# Out:
#                  부서   성명      원번         일 요일  일별근로시간(분)   일별근로시간  \
# 0             심사총괄실  민기훈  201913  20230126  목        622  1일 2:22
# 1       중대사고·리스크평가실  강경민  201033  20230120  금        615  1일 2:15
# 2       중대사고·리스크평가실  김은호  201638  20230117  화        725  1일 4:05
# 3             품질평가실  장현섭  200205  20230106  금        442     7:22
# 4             품질평가실  장현섭  200205  20230116  월        402     6:42
# 5             품질평가실  김연승  201037  20230116  월        366     6:06
# 6          의료방사선평가실  김지영  201038  20230111  수        510  1일 0:30
# 7           한울주재검사팀  장도윤  201553  20230106  금        356     5:56
# 8           한울주재검사팀  장도윤  201553  20230120  금        403     6:43
# 9           한울주재검사팀  장도윤  201553  20230127  금        352     5:52
# 10       방사선·폐기물평가실  김병일  201508  20230112  목        534  1일 0:54
# 11         방사선사건평가실  박창수  200708  20230104  수        443     7:23
# 12      공항만방사선감시평가실  이종현  201958  20230117  화        401     6:41
# ...

# %%
a2302_1['휴가'].str.contains('\d+일\d+시간+\d+분',regex=True)
# Out:
# 0     False
# 1       NaN
# 2       NaN
# 3     False
# 4     False
# 5       NaN
# 6     False
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12    False
# 13      NaN
# 14    False
# 15     True
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# Name: 휴가, dtype: object

# %%
a2302_1['휴가']= a2302_1['휴가'].str.replace(r'\d+일\d+시간+\d+분','')
# Out:
# <ipython-input-35-d1851e02c8b3>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   a2302_1['휴가']= a2302_1['휴가'].str.replace(r'\d+일\d+시간+\d+분','')

# %%
a2302_1['휴가']=a2302_1['휴가'].str.replace(r'\d+일\d+시간\d+분','',regex=True)

# %%
a2302_1
# Out:
#                  부서   성명      원번         일 요일  일별근로시간(분)   일별근로시간  \
# 0             심사총괄실  민기훈  201913  20230126  목        622  1일 2:22
# 1       중대사고·리스크평가실  강경민  201033  20230120  금        615  1일 2:15
# 2       중대사고·리스크평가실  김은호  201638  20230117  화        725  1일 4:05
# 3             품질평가실  장현섭  200205  20230106  금        442     7:22
# 4             품질평가실  장현섭  200205  20230116  월        402     6:42
# 5             품질평가실  김연승  201037  20230116  월        366     6:06
# 6          의료방사선평가실  김지영  201038  20230111  수        510  1일 0:30
# 7           한울주재검사팀  장도윤  201553  20230106  금        356     5:56
# 8           한울주재검사팀  장도윤  201553  20230120  금        403     6:43
# 9           한울주재검사팀  장도윤  201553  20230127  금        352     5:52
# 10       방사선·폐기물평가실  김병일  201508  20230112  목        534  1일 0:54
# 11         방사선사건평가실  박창수  200708  20230104  수        443     7:23
# 12      공항만방사선감시평가실  이종현  201958  20230117  화        401     6:41
# ...

# %%
a2302_1['휴가']   =a2302['휴가'].str.split(',')
a2302_1['출장']   =a2302['출장'].str.split(',')
a2302_1['출/퇴근']=a2302['출/퇴근'].str.split(',')
a2302_1
# Out:
#                  부서   성명      원번         일 요일  일별근로시간(분)   일별근로시간  \
# 0             심사총괄실  민기훈  201913  20230126  목        622  1일 2:22
# 1       중대사고·리스크평가실  강경민  201033  20230120  금        615  1일 2:15
# 2       중대사고·리스크평가실  김은호  201638  20230117  화        725  1일 4:05
# 3             품질평가실  장현섭  200205  20230106  금        442     7:22
# 4             품질평가실  장현섭  200205  20230116  월        402     6:42
# 5             품질평가실  김연승  201037  20230116  월        366     6:06
# 6          의료방사선평가실  김지영  201038  20230111  수        510  1일 0:30
# 7           한울주재검사팀  장도윤  201553  20230106  금        356     5:56
# 8           한울주재검사팀  장도윤  201553  20230120  금        403     6:43
# 9           한울주재검사팀  장도윤  201553  20230127  금        352     5:52
# 10       방사선·폐기물평가실  김병일  201508  20230112  목        534  1일 0:54
# 11         방사선사건평가실  박창수  200708  20230104  수        443     7:23
# 12      공항만방사선감시평가실  이종현  201958  20230117  화        401     6:41
# ...

# %%
a2302_2 = a2302_1[['성명','원번','일','요일','출/퇴근','출장','휴가']]
a2302_2['출/퇴근']=a2302_2['출/퇴근'].fillna('')
a2302_2['출장']=a2302_2['출장'].fillna('')
a2302_2['휴가']=a2302_2['휴가'].fillna('')
#a2302_2['근태']=a2302_2['출/퇴근']+a2302_2['출장']+a2302_2['휴가']
a2302_2
# Out:
# <ipython-input-69-49a6b34ca929>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a2302_2['출/퇴근']=a2302_2['출/퇴근'].fillna('')
# <ipython-input-69-49a6b34ca929>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a2302_2['출장']=a2302_2['출장'].fillna('')
# <ipython-input-69-49a6b34ca929>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#a2302_2['근태'] = a2302_2[['출/퇴근','출장','휴가']].apply(lambda row: ', '.join(row.dropna()), axis=1)
a2302_2['근태'] = a2302_2[['출/퇴근','출장','휴가']].apply(lambda row: ', '.join(map(str, row.dropna())), axis=1)
a2302_2
# Out:
# <ipython-input-71-841f1aaed1df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a2302_2['근태'] = a2302_2[['출/퇴근','출장','휴가']].apply(lambda row: ', '.join(map(str, row.dropna())), axis=1)
#      성명      원번         일 요일                                     출/퇴근  \
# 0   민기훈  201913  20230126  목               [07:38~18:45, 20:35~20:50]
# 1   강경민  201033  20230120  금  [07:38~12:23, 13:13~17:06, 17:58~19:58]
# 2   김은호  201638  20230117  화               [07:42~18:30, 18:58~21:15]
# 3   장현섭  200205  20230106  금               [07:00~09:00, 13:58~17:20]
# 4   장현섭  200205  20230116  월               [07:00~10:06, 18:52~19:28]
# 5   김연승  201037  20230116  월               [07:00~08:30, 10:54~16:30]
# ...

# %%
a2302.loc[a2302['원번']=='201913',a2302['출/퇴근'][0]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-6ce8f8a244af> in <cell line: 1>()
# ----> 1 a2302.loc[a2302['원번']=='201913',a2302['출/퇴근'][0]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
a = ['a','b','c']
a[0]
# Out:
# 'a'

# %%
a2302['출/퇴근'][0][0],a2302['출/퇴근'][0][1]
# Out:
# ('07:38~18:45', '20:35~20:50')
