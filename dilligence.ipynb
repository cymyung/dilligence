# %% [markdown]
# <a href="https://colab.research.google.com/github/cymyung/dilligence/blob/main/dilligence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
a2301 = pd.read_excel('https://raw.githubusercontent.com/cymyung/dilligence/main/2023_01.xlsx')

# %%
a2301.head()
# Out:
#    부서   성명      원번         일 요일  일별근로시간(분)   일별근로시간         출/퇴근 출/퇴근(시간)  \
# 0  감사  이제항  951209  20230101  일          0      NaN          NaN      NaN
# 1  감사  이제항  951209  20230102  월        468     7:48  08:58~17:46     7:48
# 2  감사  이제항  951209  20230103  화        450     7:30  09:01~17:31     7:30
# 3  감사  이제항  951209  20230104  수        480  1일 0:00          NaN      NaN
# 4  감사  이제항  951209  20230105  목        480  1일 0:00          NaN      NaN
#
#     출장 출장(시간)                 휴가   휴가(시간)  조식여부 석식여부
# 0  NaN    NaN                NaN      NaN   NaN  NaN
# 1  NaN    NaN                NaN      NaN   NaN  NaN
# 2  NaN    NaN                NaN      NaN   NaN  NaN
# 3  NaN    NaN  (연차휴가)09:00~18:00  1일 0:00   NaN  NaN
# 4  NaN    NaN  (경조휴가)09:00~18:00  1일 0:00   NaN  NaN

# %%
url = 'https://github.com/cymyung/data-science/blob/main/2023_01.xlsx'

# %%
import requests
from pprint import pprint
response = requests.get(url)
pprint(response.content)
# Out:
# (b'{"payload":{"allShortcutsEnabled":false,"fileTree":{"":{"items":[{"name":".g'
#  b'itattributes","path":".gitattributes","contentType":"file"},{"name":".gitign'
#  b'ore","path":".gitignore","contentType":"file"},{"name":"2023_01.xlsx","path"'
#  b':"2023_01.xlsx","contentType":"file"},{"name":"Python_data01.ipynb","path":"'
#  b'Python_data01.ipynb","contentType":"file"},{"name":"numpy_study","path":"num'
#  b'py_study","contentType":"file"},{"name":"numpy_study.ipynb","path":"numpy_st'
#  b'udy.ipynb","contentType":"file"},{"name":"numpy_study1.ipynb","path":"numpy_'
#  b'study1.ipynb","contentType":"file"},{"name":"numpy_study1_ipynb.ipynb","path'
#  b'":"numpy_study1_ipynb.ipynb","contentType":"file"},{"name":"numpy_study2.ipy'
#  b'nb","path":"numpy_study2.ipynb","contentType":"file"},{"name":"numpystudy_24'
#  b'0122.ipynb","path":"numpystudy_240122.ipynb","contentType":"file"},{"name":"'
#  b'pandas_study.ipynb","path":"pandas_study.ipynb","contentType":"file"},{"name'
#  b'":"pandas_study1.ipynb","path":"pandas_study1.ipynb","contentType":"file"},{'
#  b'"name":"python-data-massage01","path":"python-data-massage01","contentType":'
#  b'"file"},{"name":"python_data_massage01.ipynb","path":"python_data_massage01.'
#  b'ipynb","contentType":"file"}],"totalCount":14}},"fileTreeProcessingTime":1.8'
#  b'424850000000002,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id"'
#  b':744926265,"defaultBranch":"main","name":"data-science","ownerLogin":"cymyun'
#  b'g","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"20'
#  b'24-01-18T09:37:44.000Z","ownerAvatar":"https://avatars.githubusercontent.com'
#  b'/u/152818692?v=4","public":true,"private":false,"isOrgOwned":false},"symbols'
#  b'Expanded":false,"treeExpanded":true,"refInfo":{"name":"main","listCacheKey":'
#  b'"v0:1705808245.0","canEdit":false,"refType":"branch","currentOid":"1563fc730'
#  b'bd2e444d13e9d6c9215b21d6593c901"},"path":"2023_01.xlsx","currentUser":null,"'
#  b'blob":{"rawLines":null,"stylingDirectives":[],"csv":null,"csvError":null,"de'
#  b'pendabotInfo":{"showConfigurationBanner":false,"configFilePath":null,"networ'
#  b'kDependabotPath":"/cymyung/data-science/network/updates","dismissConfigurati'
#  b'onNoticePath":"/settings/dismiss-notice/dependabot_configuration_notice","co'
#  b'nfigurationNoticeDismissed":null,"repoAlertsPath":"/cymyung/data-science/sec'
#  b'urity/dependabot","repoSecurityAndAnalysisPath":"/cymyung/data-science/setti'
#  b'ngs/security_analysis","repoOwnerIsOrg":false,"currentUserCanAdminRepo":fals'
#  b'e},"displayName":"2023_01.xlsx","displayUrl":"https://github.com/cymyung/dat'
#  b'a-science/blob/main/2023_01.xlsx?raw=true","headerInfo":{"blobSize":"1.22 MB'
#  b'","deleteInfo":{"deleteTooltip":"You must be signed in to make or propose ch'
#  b'anges"},"editInfo":{"editTooltip":"You must be signed in to make or propose '
#  b'changes"},"ghDesktopPath":"https://desktop.github.com","gitLfsPath":null,"on'
#  b'Branch":true,"shortPath":"118466f","siteNavLoginPath":"/login?return_to=http'
#  b's%3A%2F%2Fgithub.com%2Fcymyung%2Fdata-science%2Fblob%2Fmain%2F2023_01.xlsx",'
#  b'"isCSV":false,"isRichtext":false,"toc":null,"lineInfo":{"truncatedLoc":null,'
#  b'"truncatedSloc":null},"mode":"file"},"image":false,"isCodeownersFile":null,"'
#  b'isPlain":false,"isValidLegacyIssueTemplate":false,"issueTemplateHelpUrl":"ht'
#  b'tps://docs.github.com/articles/about-issue-and-pull-request-templates","issu'
#  b'eTemplate":null,"discussionTemplate":null,"language":null,"languageID":null,'
#  b'"large":true,"loggedIn":false,"newDiscussionPath":"/cymyung/data-science/dis'
#  b'cussions/new","newIssuePath":"/cymyung/data-science/issues/new","planSupport'
#  b'Info":{"repoIsFork":null,"repoOwnedByCurrentUser":null,"requestFullPath":"/c'
#  b'ymyung/data-science/blob/main/2023_01.xlsx","showFreeOrgGatedFeatureMessage"'
#  b':null,"showPlanSupportBanner":null,"upgradeDataAttributes":null,"upgradePath'
#  b'":null},"publishBannersInfo":{"dismissActionNoticePath":"/settings/dismiss-n'
#  b'otice/publish_action_from_dockerfile","dismissStackNoticePath":"/settings/di'
#  b'smiss-notice/publish_stack_from_file","releasePath":"/cymyung/data-science/r'
#  b'eleases/new?marketplace=true","showPublishActionBanner":false,"showPublishSt'
#  b'ackBanner":false},"rawBlobUrl":"https://github.com/cymyung/data-science/raw/'
#  b'main/2023_01.xlsx","renderImageOrRaw":true,"richText":null,"renderedFileInfo'
#  b'":null,"shortPath":null,"tabSize":8,"topBannersInfo":{"overridingGlobalFundi'
#  b'ngFile":false,"globalPreferredFundingPath":null,"repoOwner":"cymyung","repoN'
#  b'ame":"data-science","showInvalidCitationWarning":false,"citationHelpUrl":"ht'
#  b'tps://docs.github.com/en/github/creating-cloning-and-archiving-repositories/'
#  b'creating-a-repository-on-github/about-citation-files","showDependabotConfigu'
#  b'rationBanner":false,"actionsOnboardingTip":null},"truncated":true,"viewable"'
#  b':false,"workflowRedirectUrl":null,"symbols":{"timed_out":true,"not_analyzed"'
#  b':true,"symbols":[],"error":{"code":"invalid_argument","msg":"content require'
#  b'd","meta":{}}}},"copilotInfo":null,"copilotAccessAllowed":false,"csrf_tokens'
#  b'":{"/cymyung/data-science/branches":{"post":"8HaWV0sTav7B3zb7-IZt3fdPJWjyrIi'
#  b'RBsa-L6J0SOuVhGU2NqGAo_ou1StyWX-MG50Mo7nRYQVDqZd5M817Tg"},"/repos/preference'
#  b's":{"post":"0AryNnY4vZ2lemVvJJBvWfykFzvJBmyBUs76dtcAbCd8XhWqV0JZYZwsi8UC_Z5Q'
#  b'v3IamTlCw-_8oOj1QdQlOA"}}},"title":"data-science/2023_01.xlsx at mai'
#  b'n \xc2\xb7 cymyung/data-science"}')

# %%
response
# Out:
# <Response [200]>
